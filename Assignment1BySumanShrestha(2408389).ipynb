# %% [markdown]
# **3 Tasks - To - Do:**
#
# Please Solve all the Problems as instructed:
#
# 3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up
# Exercises:
#
# **1. Data Exploration and Understanding:**
#
# • Dataset Overview:
#
# 1. Load the dataset and display the first 10 rows.
#
# 2. Identify the number of rows and columns in the dataset.
#
# 3. List all the columns and their data types.

# %%
import pandas as pd
#reading the csv file
df = pd.read_csv("/content/drive/MyDrive/dataset/WHR-2024-5CS037.csv")
#displaying the first 10 data from given dataset.
df.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
# displaying the total row and column present in dataset using shape function where 1st is row and 2nd is column
df.shape
# Out:
# (143, 9)

# %%
#showing columns and data types present in dataset
df.dtypes
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# **• Basic Statistics:**
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.

# %%
# calculating mean of score
print(df["score"].mean())
# Out:
# 5.52758041958042

# %%
# claculating meadian
print(df["score"].median())
# Out:
# 5.785

# %%
#calculating standard division
print(df["score"].std())
# Out:
# 1.1707165099442995

# %%
# finding minimum sorce indexing with .loc and idxmin()
min = df.loc[df["score"].idxmin()]
# printing country name and score with minimum score
print("lowest happiness score = ",min['Country name'],min['score'])
# Out:
# lowest happiness score =  Afghanistan 1.721

# %%
max = df.loc[df["score"].idxmax()]
print("Higest happiness score = " ,max['Country name'],max['score'] )
# Out:
# Higest happiness score =  Finland 7.741

# %% [markdown]
# **• Missing Values:**
#
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
# finding missing value with .isnull()
missing = df.isnull().sum()
print(missing)
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# **• Filtering and Sorting:**
#
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
feltering = df[df["score"]>7.5]
print(feltering[['Country name','score']])
# Out:
#   Country name  score
# 0      Finland  7.741
# 1      Denmark  7.583
# 2      Iceland  7.525

# %%
# displaying the feltered rows in descending oreder
sorting = feltering.sort_values(by='Log GDP per capita',ascending=False)
print(sorting.head(10))
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %%
# displaying top 10 rows sorted according to GDP per capita
sorting = df.sort_values(by='Log GDP per capita',ascending=False)
print(sorting.head(10))
# Out:
#                  Country name  score  Log GDP per capita  Social support  \
# 7                  Luxembourg  7.122               2.141           1.355
# 16                    Ireland  6.838               2.129           1.390
# 29                  Singapore  6.523               2.118           1.361
# 21       United Arab Emirates  6.733               1.983           1.164
# 8                 Switzerland  7.060               1.970           1.425
# 6                      Norway  7.302               1.952           1.517
# 22              United States  6.725               1.939           1.392
# 85  Hong Kong S.A.R. of China  5.316               1.909           1.184
# 1                     Denmark  7.583               1.908           1.520
# 5                 Netherlands  7.319               1.901           1.462
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 7                     0.708                         0.801       0.146
# ...

# %% [markdown]
# **• Adding New Columns:**
#
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
#
#                        Low − (Score < 4)
#
#                        Medium − (4 ≤ Score ≤ 6)
#
#                        High − (Score > 6)

# %%
# creating function where condition is applied
def C_Score(score):
  if score<4:
    return 'low'
  elif 4<=score <=6:
    return 'Medium'
  else:
    return 'High'
    # new column is created and (High,medium and low ) is applied according to condition
df['Happiness Category'] = df['score'].apply(C_Score)
# displaying result
df[['Country name','Happiness Category']]
# Out:
#          Country name Happiness Category
# 0             Finland               High
# 1             Denmark               High
# 2             Iceland               High
# 3              Sweden               High
# 4              Israel               High
# ..                ...                ...
# 138  Congo (Kinshasa)                low
# 139      Sierra Leone                low
# 140           Lesotho                low
# 141           Lebanon                low
# 142       Afghanistan                low
#
# [143 rows x 2 columns]

# %% [markdown]
# 2**. Data Visualizations:**
#
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
#
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.
#
# • Plot a histogram for the Score column to show its distribution and also interpret.
#
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
import matplotlib.pyplot as plt
sorted_value = df.sort_values(by = 'score',ascending=False).head(10)
# setting size of plt
plt.figure(figsize=(10,6))
plt.bar(sorted_value['Country name'],sorted_value['score'],color = 'green')
# Adding labels and title
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.title('Top 10 Happiest Countries by Score')
# displaying the plot
plt.show()

# %%
sor = df.sort_values(by = 'score',ascending=True).head(10)
plt.figure(figsize=(15,6))
# plotting unhappiest in line graph
plt.plot(sor['Country name'],sor['score'], marker='o',linestyle = '-',color = 'green')
# Adding labels and title
plt.xlabel('UnHappiness Score')
plt.ylabel('Country')
plt.title('Top 10 Unhappiest Countries by Score')
# displaying the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
# bins=10 divides the data into 10 intervals
plt.hist(df['score'], bins=11, color='green', edgecolor='black')
# Adding labels and title
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.title('Distribution of Scores')
# Show the plot
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['Log GDP per capita'],df['score'],color = "green")
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.title('Scatter Plot: GDP per Capita vs Score')
plt.show()

# %% [markdown]
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
#
# Steps:
#
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
# creating list
South_Asia =  ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Srilanka"]
# feltering or checking if maching country name is found in above list if available the created variable will hold the matched country name  all rows.
South_Asia_df = df[df['Country name'].isin(South_Asia)]
# saving data into new csv dile
South_Asia_df.to_csv('separate.csv',index=False)
sep_df = pd.read_csv('/content/separate.csv')
sep_df
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3   Bangladesh  3.886               1.122           0.249
# 4  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.513                         0.775       0.140
# 4                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual Happiness Category
# 0                      0.115                1.783             Medium
# ...

# %% [markdown]
# Task - 2 - Composite Score Ranking:
#
# Tasks:
#
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support + 0.30 × Healthy Life Expectancy
#
# 2. Rank the South Asian countries based on the Composite Score in descending order.
#
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
#
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
# creating the new column asking south asia data frame with above given operation
sep_df['Composite Score'] = (0.40*sep_df['Log GDP per capita']+0.30*sep_df['Social support']+0.30*sep_df['Healthy life expectancy'])
# shorting value in decending order with top 5 data
South = sep_df.sort_values(by='Composite Score', ascending = False).head(5)
print(South[['Country name','Composite Score']])
# Out:
#   Country name  Composite Score
# 0        Nepal           0.8159
# 2        India           0.7874
# 1     Pakistan           0.7039
# 3   Bangladesh           0.6774
# 4  Afghanistan           0.3238

# %%
plt.figure(figsize=(10,6))
plt.barh(South['Country name'], South['Composite Score'], color = 'green')
plt.xlabel('Composite Score')
plt.title('Top 5 South Asian Countries by Composite Score')
plt.show()

# %%
plt.barh(South['Country name'],South['Composite Score'],color = 'black',label = 'Composite Score')
plt.barh(South['Country name'],South['score'],color = 'blue',alpha=0.2,label = 'Score')
plt.title('Comparison of Composite Score and Original Score for Top 5 Countries')
plt.legend()
plt.show()

# %% [markdown]
# Above horizontal bar chart shows the output of top 5 countries Composite score and their orginal score.  According to this bar graph nepal have high orginal score and Composite score as well then other country  which mean social suuport,gdp per capita and healthy life expectancy also highest in this country. then looking towards Afghanistan have lowest original and composite score which mean social suuport,gdp per capita and healthy life expectancy also loww in this country. Remaning three contries composite score is almost equal but india has little higher compositer score and pakistan has higher original score.

# %% [markdown]
# **Task - 3 - Outlier Detection:**
#
# Tasks:
#
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
#
# 2. Define outliers using the 1.5 × IQR rule
# .
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
#
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
def detection(df,column):
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  Iqr = Q3-Q1
  lower_bound = Q1 - 1.5*Iqr
  upper_bound = Q3+ 1.5*Iqr
  outliers = df[(df[column]<lower_bound)|(df[column]>upper_bound)]
  return outliers

score_outliers = detection(sep_df,'score')
gdp_outliers = detection(sep_df,'Log GDP per capita')

outliers_combined = pd.concat([score_outliers, gdp_outliers]).drop_duplicates()

plt.scatter(sep_df['Log GDP per capita'],sep_df['score'], color = 'green', label = 'Normal Countries')

plt.scatter(outliers_combined['Log GDP per capita'],outliers_combined['score'], color = 'red', label = 'Outliers')

plt.xlabel('ADP per capita')
plt.ylabel('Score')
plt.title('Outlier Detection: GDP per Capita vs Score')
plt.legend()
plt.show()

# %% [markdown]
# Outliers are extrime highest or lowest values than the majority of the data points. Due to having very low log GDP capita and  Low score this outliers is decteted which reflect towards the poor economic condition and limited social support. Taking about potential impact on regional averages is the reasonal average is will not be accurate.

# %% [markdown]
# **Task - 4 - Exploring Trends Across Metrics:**
#
# Tasks:
#
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.
#
# 2. Create scatter plots with trendlines for these metrics against the Score.
#
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
import seaborn as sns
freedom = sep_df['Freedom to make life choices'].corr(sep_df['score'])
generosity = sep_df['Generosity'].corr(sep_df['score'])

print("Correlation between Freedom to Make Life Choices and Score:", freedom)
print("Correlation between Generosity and Score:", generosity)

plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
sns.regplot(x = 'Freedom to make life choices',y='score',data = sep_df, color='green')
plt.title('Score vs Freedom to Make Life Choices')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')

plt.subplot(1,2,2)
sns.regplot(x='Generosity', y='score', data=sep_df, color='blue')
plt.title('Score vs Generosity')
plt.xlabel('Generosity')
plt.ylabel('Score')

plt.tight_layout()
plt.show()
# Out:
# Correlation between Freedom to Make Life Choices and Score: 0.801497903141921
# Correlation between Generosity and Score: 0.8773326267276359

# %% [markdown]
# Task - 5 - Gap Analysis:
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
# calculating GFP score
sep_df['GDP score Gap'] = sep_df['Log GDP per capita']-sep_df['score']

sorting_ascending = sep_df.sort_values(by ='GDP score Gap',ascending = True )
sorting_descending = sep_df.sort_values(by ='GDP score Gap',ascending = False )

positive_gap = sorting_descending.head(3)
negative_gap = sorting_ascending.head(3)

plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
plt.barh(positive_gap['Country name'], positive_gap['GDP score Gap'], color='green')
plt.title('Top 3 Positive GDP score Gaps')
plt.xlabel('GDP Score Gap')

plt.subplot(1,2,2)
plt.barh(negative_gap['Country name'], negative_gap['GDP score Gap'], color='red')
plt.title('Top 3 negetive GDP score Gaps')
plt.xlabel('GDP Score Gap')

plt.show()

# %% [markdown]
# **3.3 Problem - 3 - Comparative Analysis:**
#
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:
#
# **Tasks:**
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]
#
# Complete the following task:
#
# **1. Descriptive Statistics:**
#
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
#
# • Which region has higher happiness Scores on average?

# %%
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan","Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]
middle_east_df = df[df['Country name'].isin(middle_east_countries)]

middle_east_mean = middle_east_df['score'].mean()
middle_east_std = middle_east_df['score'].std()

south_mean = sep_df['score'].mean()
south_std = sep_df['score'].std()

print("South Asia - Mean Happiness Score:", south_mean)
print("South Asia - Standard Deviation of Happiness Score:", south_std)

print("\nMiddle East - Mean Happiness Score:", middle_east_mean)
print("Middle East - Standard Deviation of Happiness Score:", middle_east_std)

if south_mean>middle_east_mean:
  print("\nSouth Asia has higher average happiness scores. ")
else:
  print("\nMiddle East has higher average happiness scores.")
# Out:
# South Asia - Mean Happiness Score: 3.8952000000000004
# South Asia - Standard Deviation of Happiness Score: 1.3160025455902433
#
# Middle East - Mean Happiness Score: 5.412100000000001
# Middle East - Standard Deviation of Happiness Score: 1.5662011684327144
#
# Middle East has higher average happiness scores.

# %% [markdown]
# 2. Top and Bottom Performers:
#
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
top_3_score_south = sep_df.sort_values(by='score',ascending = False).head(3)
top_3_score_middle = middle_east_df.sort_values(by='score',ascending = False).head(3)
bottom_3_score_south = sep_df.sort_values(by = 'score',ascending = True).head(3)
bottom_3_score_middle = middle_east_df.sort_values(by = 'score',ascending = True).head(3)

print("\n Top 3 score in south asia")
print(top_3_score_south[['Country name','score']])
print("\n buttom 3 score in south asia")
print(bottom_3_score_south[['Country name','score']])
print("\n Top 3 score in middle east")
print(top_3_score_middle[['Country name','score']])
print("\n buttom 3 score in middle east")
print(bottom_3_score_middle[['Country name','score']])
plt.figure(figsize=(22,8))

plt.barh(top_3_score_south['Country name'],top_3_score_south['score'],color = 'red',label = 'top 3 score of South Asia')
plt.barh(top_3_score_middle['Country name'],top_3_score_middle['score'],color = 'blue',label = 'top 3 score of middle east')
plt.title('Top 3 Performers in South Asia and Middle East')
plt.ylabel('Score')
plt.legend()

plt.barh(bottom_3_score_south['Country name'],bottom_3_score_south['score'],color = 'yellow',alpha = 0.6,label = 'bottom 3 score south asia')
plt.barh(bottom_3_score_middle['Country name'],bottom_3_score_middle['score'],color = 'green',label = 'bottom 3 score middle east')
plt.title('Top 3 Performers in South Asia and Middle East')
plt.ylabel('Score')
plt.legend()


plt.show()
# Out:
#  Top 3 score in south asia
#   Country name  score
# 0        Nepal  5.158
# 1     Pakistan  4.657
# 2        India  4.054
#
#  buttom 3 score in south asia
#   Country name  score
# 4  Afghanistan  1.721
# 3   Bangladesh  3.886
# 2        India  4.054
#
#  Top 3 score in middle east
#             Country name  score
# 4                 Israel  7.341
# 12                Kuwait  6.951
# 21  United Arab Emirates  6.733
#
#  buttom 3 score in middle east
#     Country name  score
# 141      Lebanon  2.707
# 132        Yemen  3.561
# 124       Jordan  4.186

# %% [markdown]
# **3. Metric Comparisons:**
#
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.
#
# • Which metrics show the largest disparity between the two regions?

# %%
import numpy as np
matrix = ['Log GDP per capita','Social support', 'Healthy life expectancy']
south_means = sep_df[matrix].mean()
middle_means = middle_east_df[matrix].mean()

group = np.arange(len(matrix))
bar_width = 0.35

plt.figure(figsize=(10,6))
plt.bar(group - bar_width/2,south_means,bar_width,label = "South Asia", color = "blue")
plt.bar(group + bar_width/2,middle_means,bar_width,label = "middle east", color = "red")
plt.xticks(group, matrix)
plt.ylabel('Mean Value')
plt.title('Comparison of Key Metrics Between South Asia and Middle East')
plt.legend()
plt.show()

largest_disparity = abs(south_means-middle_means).idxmax()

print("Metric with the largest disparity:", largest_disparity)
print(f"Disparity: {abs(south_means-middle_means)[largest_disparity]:.2f}")
# Out:
# Metric with the largest disparity: Social support
# Disparity: 0.65

# %% [markdown]
# 4. Happiness Disparity:
#
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
#
# • Which region has greater variability in happiness?

# %%
south_range = sep_df['score'].max()-sep_df['score'].min()
south_cv = (sep_df['score'].std()/sep_df['score'].mean())*100

middle_range = middle_east_df['score'].max()-middle_east_df['score'].min()
middle_cv = (middle_east_df['score'].std()/middle_east_df['score'].mean())*100

print("South Asia - Range: ",south_range)
print("Middle East - Range: ",middle_range)

print('\n South Asia - Coefficient of Variation (CV): ',south_cv)
print('\n Middle East - Coefficient of Variation (CV): ',middle_cv)

if south_cv > middle_cv:
  print("\n South Asia has greater Variability in happiness (based on cv).")
else:
  print("\n Middle East has greater Variability in happiness (based on cv).")
# Out:
# South Asia - Range:  3.4370000000000003
# Middle East - Range:  4.634
#
#  South Asia - Coefficient of Variation (CV):  33.785236845097636
#
#  Middle East - Coefficient of Variation (CV):  28.938880812119404
#
#  South Asia has greater Variability in happiness (based on cv).

# %% [markdown]
# 5. Correlation Analysis:
#
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
#
# • Create scatter plots to visualize and interpret the relationships.

# %%
south_correlation_freedom = sep_df['score'].corr(sep_df['Freedom to make life choices'])
south_correlation_generosity =  sep_df['score'].corr(sep_df['Generosity'])

south_correlation_freedom = middle_east_df['score'].corr(middle_east_df['Freedom to make life choices'])
middle_correlation_generosity =  middle_east_df['score'].corr(middle_east_df['Generosity'])

plt.figure(figsize=(14,10))
plt.subplot(2,2,1)
plt.scatter(sep_df['Freedom to make life choices'], sep_df['score'],color = 'blue')
z = np.polyfit(sep_df['Freedom to make life choices'],sep_df['score'],1)
p = np.poly1d(z)
plt.plot(sep_df['Freedom to make life choices'],p(sep_df['Freedom to make life choices']))
plt.title("South Asia: Freedom to Make Life Choices vs Score")
plt.xlabel("Freedom to Make Life Choices")
plt.ylabel("Score")

plt.subplot(2,2,2)
plt.scatter(sep_df['Generosity'], sep_df['score'],color = 'blue')
z1 = np.polyfit(sep_df['Generosity'],sep_df['score'],1)
p1 = np.poly1d(z1)
plt.plot(sep_df['Generosity'],p1(sep_df['Generosity']))
plt.title("South Asia: Freedom to Make Life Choices vs Score")
plt.xlabel("Freedom to Make Life Choices")
plt.ylabel("Score")



plt.subplot(2,2,3)
plt.scatter(middle_east_df['Freedom to make life choices'], middle_east_df['score'],color = 'blue')
plt.title("South Asia: Freedom to Make Life Choices vs Score")
plt.xlabel("Freedom to Make Life Choices")
plt.ylabel("Score")

plt.subplot(2,2,4)
plt.scatter(middle_east_df['Generosity'], middle_east_df['score'],color = 'blue')
plt.title("South Asia: Freedom to Make Life Choices vs Score")
plt.xlabel("Freedom to Make Life Choices")
plt.ylabel("Score")
plt.show()


print("South Asia Correlation:")
print(f"Freedom to Make Life Choices: {south_correlation_freedom}")
print(f"Generosity: {south_correlation_generosity}\n")

print("Middle East Correlation:")
print(f"Freedom to Make Life Choices: {south_correlation_freedom}")
print(f"Generosity: {south_correlation_generosity}")
# Out:
# South Asia Correlation:
# Freedom to Make Life Choices: 0.8632202433827544
# Generosity: 0.8773326267276358
#
# Middle East Correlation:
# Freedom to Make Life Choices: 0.8632202433827544
# Generosity: 0.8773326267276358

# %% [markdown]
# 6. Outlier Detection:
#
# • Identify outlier countries in both regions based on Score and GDP per Capita.
#
# • Plot these outliers and discuss their implications.

# %%
def outliers_detection(data,column):
  Q1 = data[column].quantile(0.25)
  Q3 = data[column].quantile(0.75)
  IQR = Q3-Q1
  lower_b = Q1 - 1.5*IQR
  upper_b = Q3 + 1.5*IQR
  return data[(data[column]<lower_b) | (data[column]>upper_b)]
south_outliers_score = outliers_detection(sep_df,'score')
south_outliers_GDP = outliers_detection(sep_df,'Log GDP per capita')

middle_outliers_score = outliers_detection(middle_east_df,'score')
middle_outliers_GDP = outliers_detection(middle_east_df,'Log GDP per capita')

plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
plt.scatter(sep_df['Log GDP per capita'],sep_df['score'], color = 'green',label = 'South Asia')
plt.scatter(south_outliers_GDP['Log GDP per capita'], south_outliers_score['score'], color='red', label='Outliers')
plt.title("South Asia: GDP per Capita vs Score (Outliers Highlighted)")
plt.xlabel("GDP per Capita")
plt.ylabel("Score")
plt.legend()


plt.subplot(1, 2, 2)
plt.scatter(middle_east_df['Log GDP per capita'], middle_east_df['score'], color='green', label='Middle East')
plt.scatter(middle_outliers_GDP['Log GDP per capita'], middle_outliers_score['score'], color='red', label='Outliers')
plt.title("Middle East: GDP per Capita vs Score (Outliers Highlighted)")
plt.xlabel("GDP per Capita")
plt.ylabel("Score")
plt.legend()

plt.show()

print("South Asia Outliers - Score:")
print(south_outliers_score[['Country name', 'score']])
print("\nSouth Asia Outliers - GDP per Capita:")
print(south_outliers_GDP[['Country name', 'Log GDP per capita']])

print("\nMiddle East Outliers - Score:")
print(middle_outliers_score[['Country name', 'score']])
print("\nMiddle East Outliers - GDP per Capita:")
print(middle_outliers_GDP[['Country name', 'Log GDP per capita']])
# Out:
# South Asia Outliers - Score:
#   Country name  score
# 4  Afghanistan  1.721
#
# South Asia Outliers - GDP per Capita:
#   Country name  Log GDP per capita
# 4  Afghanistan               0.628
#
# Middle East Outliers - Score:
# Empty DataFrame
# Columns: [Country name, score]
# Index: []
#
# Middle East Outliers - GDP per Capita:
# Empty DataFrame
# Columns: [Country name, Log GDP per capita]
# Index: []

# %% [markdown]
# According to above result there are not outliers in misdle east country.

# %% [markdown]
# & Visualization:
#
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Srilanka"]
south_asia_data_df = df[df['Country name'].isin(south_asian_countries)]
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan","Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]
middle_df = df[df['Country name'].isin(middle_east_countries)]
south_asia_data_df['Region'] = 'South Asia'
middle_df['Region'] = 'middle east'
combined_df = pd.concat([
    south_asia_data_df.assign(Region = 'South Asia'),
    middle_df.assign(Region='middle east')
])
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=combined_df, palette='pastel', width=0.6)
plt.title('Comparison of Score Distribution: South Asia vs Middle East')
plt.ylabel('score')
plt.xlabel('Region')
plt.show()
# Out:
# <ipython-input-36-2f8590129c3f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asia_data_df['Region'] = 'South Asia'
# <ipython-input-36-2f8590129c3f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   middle_df['Region'] = 'middle east'
# <ipython-input-36-2f8590129c3f>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...
